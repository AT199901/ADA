# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Numpy converts all the values into a number
# Matplotlib is the library for graphs

# %%
# %matplotlib inline

# %%
rng = np.random.RandomState(0)

# %%
# For the below:
# linspace will generate a number
# x axis is between 0 and 10
# 100 values altogether

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 10, 100)

plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))

plt.show()

# %%
# make dotted lines by passing the argument '--'
# make straight lines by passing argument '-'

fig = plt.figure()
plt.plot(x, np.sin(x), '-')
plt.plot(x, np.cos(x), '--');

# %%
# first value is number of subplots

plt.figure() 


plt.subplot(2, 1, 1)
plt.plot(x, np.sin(x))


plt.subplot(2, 1, 2)
plt.plot(x, np.cos(x));

# %%
x = np.linspace(0, 10, 250)
y = np.cumsum(rng.randn(250, 6), 0)

# %%
# delta function cumsum
# It calculates to n-th discrete difference along
# given axis

# It generates a random number
# Then plots on the graph
# axis is 0 to 10
# 250 points
# For the y axis, we use cumsum value and it
# generates

plt.plot(x, y)
plt.legend('ABCDEF', ncol=2, loc='best')

# %%
import seaborn as sns
tips=sns.load_dataset('tips')

# %%
sns.set()

plt.plot(x, y)
plt.legend('ABCDEF', ncol=2, loc='upper left')

# %%
iris = sns.load_dataset("iris")

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.petal_length.plot()
# Out:
# <AxesSubplot:>

# %%
iris.plot()

# numpy is for dealing with numbers
# pandas is for dealing with the entire dataframe
# Out:
# <AxesSubplot:>

# %%
plt.plot(iris.sepal_length,iris.sepal_width, "o")

# %%
plt.plot(iris.sepal_length,iris.sepal_width, "+")

# %%
plt.plot(iris.sepal_length,iris.sepal_width, "v")

# %%
plt.plot(iris.sepal_length,iris.sepal_width, "rv")

# %%
plt.plot(iris.sepal_length,iris.sepal_width, 
         "rv", markersize=10)

# %%
plt.scatter(iris.sepal_length,iris.sepal_width)

# %%
plt.scatter(iris.sepal_length,
            iris.sepal_width,s=75)

# %%
plt.scatter(iris.sepal_length,iris.sepal_width, 
            s=75, c="m")

# %%
plt.scatter(iris.sepal_length,iris.sepal_width, 
            s=75, c="m", marker="v")

# %%
plt.scatter(iris.sepal_length,iris.sepal_width, 
            s=75, c="m", 
            edgecolor="black", 
            linewidth=1)

# %%
plt.scatter(iris.sepal_length,iris.sepal_width,
            s=75, c="m", 
            edgecolor="black", 
            linewidth=1, 
            alpha=0.5)

# %%
color=np.random.randint(0,10,150)
plt.scatter(iris.sepal_length,iris.sepal_width, 
            s=100, 
            c=color, 
            edgecolor="black", 
            linewidth=1, 
            alpha=1)

# %%
plt.scatter(iris.sepal_length,iris.sepal_width, 
            s=100, 
            c=color, 
            cmap="Reds", 
            edgecolor="black", 
            linewidth=1, 
            alpha=1)

# %%
plt.scatter(iris.sepal_length,iris.sepal_width, 
            s=100, 
            c=color, 
            cmap="viridis", 
            edgecolor="black", 
            linewidth=1, 
            alpha=1)

# %%
plt.scatter(iris.sepal_length,iris.sepal_width, 
            s=100, 
            c=color, 
            cmap="viridis", 
            edgecolor="black", 
            linewidth=1, 
            alpha=1)
cbar=plt.colorbar()

# %%
plt.scatter(iris.sepal_length,iris.sepal_width, 
            s=100, 
            c=color, 
            cmap="viridis", 
            edgecolor="black", 
            linewidth=1, 
            alpha=1)
cbar=plt.colorbar()
cbar.set_label("Levels")

# %%
plt.scatter(iris.sepal_length,iris.sepal_width, 
            s=100,  
            c=color, 
            cmap="Reds",
            edgecolor="black",
            linewidth=1, 
            alpha=1)
plt.xlabel("sepal_width")
plt.ylabel("petal_length")
plt.title("İris Sepal Length & Sepal Width ")
# Out:
# Text(0.5, 1.0, 'İris Sepal Length & Sepal Width ')

# %%
setosa=iris.loc[iris.species== "setosa"]
virginica = iris.loc[iris.species == "virginica"]

# %%
setosa.sepal_length.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
sns.kdeplot(
    setosa.sepal_length, shade=True, color="r")
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='Density'>

# %%
sns.histplot(iris.sepal_length, kde=True)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='Count'>

# %%
sns.histplot(
    iris.sepal_length, kde=True, color="r")
sns.histplot(
    iris.sepal_width, kde=True,color="b")
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='Count'>

# %%
sns.kdeplot(
    data=iris, x="sepal_length", y="sepal_width")
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.kdeplot(
    data=iris, x="sepal_length", 
    y="sepal_width", shade=True)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
with sns.axes_style('white'):
    sns.jointplot(
        data= iris, x="sepal_length", 
        y="sepal_width", kind='hex')

# %%
sns.pairplot(iris, hue='species')

# %%
tips=sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips["tip_percent"]=tips[
    "tip"]*100/tips["total_bill"]

# %%
grid=sns.FacetGrid(
    tips, row="smoker",col="time", 
    margin_titles=True)

# %%
grid.map(
    plt.hist, "tip_percent", 
    bins=np.linspace(0,40,15))

# %%
Math=np.random.randint(50,100,7)
Stat=np.random.randint(50,100,7)
CS=np.random.randint(50,100,7)

classes=list("ABCDEFG")

# %%
plt.plot(classes, Math, label="Math Avg")
plt.plot(classes, Stat, label="Stat Avg")
plt.plot(classes, CS, label="CS Avg")
plt.legend()
plt.title("Average of Lessons")
plt.xlabel("Classes")
plt.ylabel("Averages")
# Out:
# Text(0, 0.5, 'Averages')

# %%
plt.bar(classes, Math, label="Math Avg")
plt.bar(classes, Stat, label="Stat Avg")
plt.bar(classes, CS, label="CS Avg")
plt.legend()
plt.title("Average of Lessons")
plt.xlabel("Classes")
plt.ylabel("Averages")
# Out:
# Text(0, 0.5, 'Averages')

# %%
x_indeks=np.arange(len(classes))
x=0.25
plt.bar(x_indeks-x,Math,width=x,label="Math Avg")
plt.bar(x_indeks,Stat,width=x,label="Stat Avg")
plt.bar(x_indeks+x, CS, width=x, label="CS Avg")
plt.legend()
plt.title("Average of Lessons")
plt.xlabel("Classes")
plt.ylabel("Averages")
# Out:
# Text(0, 0.5, 'Averages')
