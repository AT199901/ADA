# %%
import pandas as pd

# %%
data = pd.read_csv('//Users/mufasa/Downloads/Crash.csv')
data.head()
# Out:
#    Crash identifier    Crash severity  Number of vehicles involved  \
# 0         201740657  Non-Injury Crash                          2.0
# 1         201740657  Non-Injury Crash                          2.0
# 2         201740742  Non-Injury Crash                          2.0
# 3         201740747  Non-Injury Crash                          2.0
# 4         201740650  Non-Injury Crash                          3.0
#
#     Simple / complex crash  Crash year Day of the week Month of year  \
# 0  Multiple Party (Simple)        2017       Wednesday           May
# 1  Multiple Party (Simple)        2017       Wednesday           May
# 2  Multiple Party (Simple)        2017          Friday         April
# 3  Multiple Party (Simple)        2017        Thursday          June
# 4  Multiple Party (Simple)        2017          Monday           May
#
#   Is weekend Holiday Road category  ... Natural Light Primary weather  \
# 0         No     NaN      Motorway  ...      Overcast            Fine
# ...

# %%
# sort the Crash identifier column in ascending order

# %%
data.sort_values('Crash identifier',ascending=True)
# Out:
#         Crash identifier    Crash severity  Number of vehicles involved  \
# 63044          201600001       Fatal Crash                          1.0
# 63060          201600001       Fatal Crash                          1.0
# 63018          201600001       Fatal Crash                          1.0
# 60298          201600002       Fatal Crash                          1.0
# 60299          201600002       Fatal Crash                          1.0
# ...                  ...               ...                          ...
# 378518        2020209429     Serious Crash                          1.0
# 378522        2020210199  Non-Injury Crash                          1.0
# 378528        2020210432  Non-Injury Crash                          1.0
# 378529        2020210447  Non-Injury Crash                          2.0
# 378544        2020210447  Non-Injury Crash                          2.0
#
#          Simple / complex crash  Crash year Day of the week Month of year  \
# ...

# %%
# The location in the dataset where column heading Road user type
# is NOT equal to Driver, it will be dropped
# AKA filter Driver under column Road user type

# %%
data.drop(data.loc[data['Road user type']!='Driver'].index, inplace=True)

# %%
data.drop(data.loc[data['Road user type']!='Driver'].index, inplace=True)

# %%
DC_Index=data.columns.get_loc("Driver contribution")
print(DC_Index)
# Out:
# 30

# %%
# Find out index number of the Driver contribution column (above)

# Find out total number of index by using data.shape[0]
# Then allocate a name to that value ie Total_Index

# Run a loop:
# for each row, or x in range Total_Index,
# if x = Primary, Partial or No Contribution, 
# count will increase by 1
# else NC will increase by 1

# %%
Total_Index=data.shape[0]
print(Total_Index)
NC_List=[]
count=0
NC=0
for x in range (Total_Index):
    if (data.iloc[x][30]=="Primary" or data.iloc[x][30]=='Partial' or data.iloc[x][30]=='No Contribution'):
      
        count+=1
    else:
        NC+=1
        NC_List.append(x)
print(count)
print(NC)
print(NC_List)
# Out:
# 321711
# 321426
# 285
# ...

# %%
# Drop NC_List, or all rows where column x[30] does not equal
# Primary, Partial or No Contribution (remove blanks)

data.drop(data.index[[11996, 11998, 23437, 189027, 189232, 189260, 189268, 189596, 189798, 189832, 189839, 189841, 189996, 190094, 190206, 190251, 190275, 190614, 190619, 190656, 190717, 190872, 190895, 190897, 191023, 191067, 191135, 191181, 191219, 191295, 192026, 192031, 192579, 195648, 195673, 196152, 196160, 196184, 196221, 196419, 196469, 196541, 196554, 197003, 197120, 197166, 197180, 197301, 197358, 197669, 197693, 197918, 197930, 197960, 198208, 198257, 198350, 198427, 198452, 198550, 198618, 198647, 198716, 198717, 198837, 198901, 199045, 199255, 199270, 199365, 199381, 199399, 199515, 199537, 199613, 199615, 199933, 199944, 200030, 200241, 200243, 200341, 200361, 200472, 200477, 200550, 200581, 200593, 200668, 200823, 200828, 200831, 200920, 200925, 200951, 201170, 201213, 201271, 201291, 201462, 201480, 201502, 201590, 201605, 201650, 201658, 201666, 201670, 201676, 201682, 201691, 201702, 201722, 201746, 201870, 201888, 201911, 201941, 201973, 202124, 202168, 202185, 202214, 202345, 202426, 202525, 202588, 202595, 202643, 202679, 202686, 202855, 203140, 203161, 203256, 203575, 203603, 203651, 203658, 203703, 203728, 203729, 203749, 203767, 203829, 203839, 203840, 203933, 203937, 203948, 204025, 204056, 204084, 204100, 204120, 204136, 204158, 204403, 205136, 205229, 205248, 205719, 206386, 207203, 207221, 207430, 207554, 207680, 207740, 207768, 207786, 207797, 207860, 207899, 207924, 207988, 207994, 208147, 208167, 208324, 208334, 208337, 208480, 208492, 208510, 208525, 208588, 208613, 208673, 208708, 208713, 208851, 208880, 208977, 209142, 209365, 209432, 209472, 209505, 209613, 209728, 210002, 210014, 210032, 210037, 210044, 210067, 210210, 210225, 210253, 210254, 210306, 210325, 210368, 210382, 210389, 210500, 210617, 210698, 210815, 210942, 211090, 211137, 211230, 211361, 211435, 211473, 211549, 211725, 211947, 211951, 212613, 212672, 212783, 212877, 212923, 213078, 213106, 213292, 213364, 213437, 213689, 213695, 213726, 213772, 213783, 213796, 213799, 213837, 213959, 214058, 214097, 214123, 214305, 214315, 214443, 215086, 215095, 215655, 215836, 216536, 226250, 228560, 228576, 228988, 230037, 234925, 237299, 237617, 239794, 247743, 247838, 254914, 257067, 265303, 278831, 290955, 293315, 296442, 300629, 306577, 308178, 313659, 313687, 315965]],inplace=True)

# %%
data.sort_values("Driver contribution", inplace = True)

# %%
# Remove duplicate Crash identifiers
# Removes any second, third, etc. duplicates
# Primary will always be listed first, so we will always keep primary
# driver contributor when applying the below function

data.drop_duplicates(subset ="Crash identifier",
                     keep = 'last', inplace = True)
data.shape
# Out:
# (184317, 36)

# %%
data.to_csv('Crash_Clean.csv', index=False)

# %%
# Start looking at some data visualisation

# Want to look at how many accidents happen each day
# Use groupby function
# Group by crash year and day of the week
# Show result in a table format:

# Row by year
# Columns by day
# Count up total number of crashes each day with each year

# Just for understanding purpose, use year as name of rows, day
# as name of columns

days = ['Sunday', 'Saturday', 'Friday', 'Thursday', 'Wednesday', 'Tuesday', 'Monday']
accident_table = data.groupby(['Crash year', 'Day of the week']).size()
accident_table = accident_table.rename_axis(['Year', 'Weekday'])\
                               .unstack('Weekday')\
                               .reindex(columns=days)
accident_table
# Out:
# Weekday  Sunday  Saturday  Friday  Thursday  Wednesday  Tuesday  Monday
# Year
# 2016       4447      5548    6373      5787       5406     5106    4545
# 2017       4951      5853    6351      6111       5680     5377    4972
# 2018       4540      5732    6338      5906       5622     5223    5093
# 2019       4543      5419    6053      5481       5332     5239    4826
# 2020       4083      4906    5053      4790       4749     4616    4266

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(10,10))
sns.heatmap(accident_table, cmap='RdYlGn',annot=True)
plt.title('\nAccidents by Years and Weekdays\n', fontsize=14, fontweight='bold')
plt.xlabel('')
plt.ylabel('');

# %%
# The above heatmap shows which days and years tend to have alot of
# crashes (in red)

# Insight:
# Sunday has the least crashes compared to other days of the week
# 2020 has the least crashes compared to other years
# Possibilities: safer roads? strict license qualification requirements?

# Thursday to Saturday sees the most crashes (end of the week)
# Friday/Saturday influenced by alcohol/drugs?
# Near the end of the week, people tired after long week?

# %%
monthly = data[['Month of year', 'Crash identifier']].groupby(['Month of year']).count()



monthly['Crash identifier'].plot.bar(figsize=(14,7), alpha=0.5, color='black', label='Total accidents')

plt.rc('xtick',labelsize=22)
plt.title('Accidents per month from 2016 to 2020')
plt.xticks(range(13))
plt.xlim(-1,12)

plt.xlabel('Month')
plt.ylabel('Accidents')
plt.legend()

# %%
# Low accidents in April and January
# January = less people working, less people on the roads,
# People near the end of their holiday so either at home, not
# travelling

# %%
monthly = data[['Day of the week', 'Crash identifier']].groupby(['Day of the week']).count()



monthly['Crash identifier'].plot.bar(figsize=(14,7), alpha=0.5, color='b', label='Total accidents')


plt.title('Accidents per month from 2016 to 2020')

plt.rcParams.update({'font.size':22})
plt.xticks(range(7))
plt.xlim(-1,7)

plt.xlabel('Day')
plt.ylabel('Accidents')
plt.legend()

# %%
week=data.groupby("Day of the week")["Crash identifier"].count()

label=week.keys()
plt.pie(x=week,radius=1.4, autopct="%.1f%%", labels=label, pctdistance=0.7)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f96a7169b80>,
# ...
#  [Text(1.3408581421968104, 0.757429496721984, 'Friday'),
#   Text(0.21247145226973763, 1.5252723959904304, 'Monday'),
#   Text(-1.031088991203411, 1.1438773938753806, 'Saturday'),
#   Text(-1.53981760160324, -0.023701345802412947, 'Sunday'),
#   Text(-0.9829826276211308, -1.1854725445133925, 'Thursday'),
#   Text(0.3389448758138771, -1.5022371221480035, 'Tuesday'),
#   Text(1.382233723527902, -0.6789918508658197, 'Wednesday')],
#  [Text(0.853273363216152, 0.48200058882308067, '16.4%'),
#   Text(0.13520910598983302, 0.9706278883575465, '12.9%'),
#   Text(-0.6561475398567159, 0.7279219779206966, '14.9%'),
#   Text(-0.9798839282929708, -0.01508267460153551, '12.2%'),
#   Text(-0.6255343993952649, -0.7543916192357951, '15.2%'),
#   Text(0.21569219369973994, -0.9559690777305475, '13.9%'),
#   Text(0.8796032786086647, -0.43208572327824885, '14.5%')])

# %%
week=data.groupby(["Crash year","Crash severity"])["Crash identifier"].count()
week
week.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Crash year,Crash severity'>

# %%
dff = pd.DataFrame(columns=('Crash Severity', 'Longitude','Latitude'))
cs=0
for i in range(data.shape[0]):
    if (data.iloc[i][1]=='Fatal Crash'):
        dff.loc[cs] = [data.iloc[i][1], data.iloc[i][17],data.iloc[i][18]]
        cs+=1
dff.plot(kind="scatter", x="Longitude", y="Latitude", color='red')
plt.ylabel("Latitude", fontsize=18)
plt.xlabel("Longitude", fontsize=18)
plt.show()

# %%
# Explanation of above plot:

# A loop that checks each row in data
# If i in column 1 (Crash Severity) equals Fatal Crash,
# Get longitude and latitude and cs increases by 1

# %%
count=0
NC_List=[]
for i in range (data.shape[0]):
    if (data.iloc[i][17]<0):
        NC_List.append(i)
        count+=1
print(count) 
print(NC_List)
# Out:
# 31
# [1676, 1680, 2088, 2794, 3145, 3234, 11123, 21990, 36632, 41168, 49424, 58941, 73673, 86609, 111886, 117085, 118020, 121076, 121521, 121978, 124697, 130029, 134639, 143507, 146032, 150497, 153579, 156903, 162780, 176607, 176937]

# %%
# Drop all values pulled into variable NC_List
# These are all rows where longitude is less than 0

data.drop(data.index[[1676, 1680, 2088, 2794, 3145, 3234, 11123, 21990, 36632, 41168, 49424, 58941, 73673, 86609, 111886, 117085, 118020, 121076, 121521, 121978, 124697, 130029, 134639, 143507, 146032, 150497, 153579, 156903, 162780, 176607, 176937]],inplace=True)

# %%
dff = pd.DataFrame(columns=('Crash Severity', 'Longitude','Latitude'))
cs=0
for i in range(data.shape[0]):
    if (data.iloc[i][1]=='Fatal Crash'):
        dff.loc[cs] = [data.iloc[i][1], data.iloc[i][17],data.iloc[i][18]]
        cs+=1
dff.plot(kind="scatter", x="Longitude", y="Latitude", marker='.', alpha=0.2, s=0.5, c='red')
plt.ylabel("Latitude", fontsize=18)
plt.xlabel("Longitude", fontsize=18)
plt.show()
